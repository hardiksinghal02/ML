# %% [markdown]
# ## Simple linear regression
#
# - Single independent variable and single dependent variable
# - Assumes relationship is a straight line
# - y = m.x + c
# - Error (Residuals) should follow Normal distribution (Gaussian)
# - Find best fit line (Ordinary Least Squares)
#   - Minimize the sum of squared error

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("Salary_Data.csv")
X = dataset.iloc[:, 0:-1].values
y = dataset.iloc[:, 1:].values

# %%
y
# Out:
# array([[ 39343.],
#        [ 46205.],
#        [ 37731.],
#        [ 43525.],
#        [ 39891.],
#        [ 56642.],
#        [ 60150.],
#        [ 54445.],
#        [ 64445.],
#        [ 57189.],
#        [ 63218.],
#        [ 55794.],
#        [ 56957.],
#        [ 57081.],
#        [ 61111.],
#        [ 67938.],
#        [ 66029.],
#        [ 83088.],
#        [ 81363.],
#        [ 93940.],
#        [ 91738.],
#        [ 98273.],
#        [101302.],
#        [113812.],
#        [109431.],
#        [105582.],
#        [116969.],
#        [112635.],
#        [122391.],
#        [121872.]])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression

regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Predicting the test set result

# %%
y_pred = regressor.predict(X_test)

# %% [markdown]
# ### Visualization

# %%
plt.scatter(X_train, y_train, color='red')
plt.plot(X_train, regressor.predict(X_train), color = 'blue')
plt.title("Salary vs Experience (Training set)")
plt.xlabel("Years of experience")
plt.ylabel("Salary")
plt.show()

# %%
plt.scatter(X_test, y_test, color='red')
plt.plot(X_test, y_pred, color = 'blue')
plt.title("Salary vs Experience (Test set)")
plt.xlabel("Years of experience")
plt.ylabel("Salary")
plt.show()

# %% [markdown]
# ### Predicting a single value

# %%
# predict method expects 2d array as input
regressor.predict([[12]])
# Out:
# array([[138531.00067138]])

# %%
print(f"Y intercept : {regressor.intercept_}")
print(f"Slope / X coefficient : {regressor.coef_}")
# Out:
# Y intercept : [26780.09915063]
# Slope / X coefficient : [[9312.57512673]]
